# %%
import pandas as pd
import requests

# %%
file='image_gallery_uk.csv'
df= pd.read_csv(file,low_memory=False)
len_df=len(df)
len_df
# Out:
# 4077935

# %% [markdown]
# After Observation from previous trail, It was noticed that the max distance that aligns with the max accepted duration should be 6 km away from the POI

# %%
df_filt_dist = df[df['distance_to_bigben'] <= 6]
df_filt_dist
# Out:
#          accommodation_id                                           image_id  \
# 215              37152666  JSC6NLCCJITBM4CUILH2O53RHDOMSTPY6AA2MWV63DJ4DH...
# 216              37152666  DXB4JJI6WFV4DAPF25QODNMD5CT36ISLV3R7DI3XVJ2QR4...
# 217              37152666  ZK747KL6GLW36PVKKV3SUWE5OWRPT4KWHWCGUYIM5RLPRH...
# 218              37152666  URBVFX5ELYSTMNB3K7V4NQEJ7GK7RT4BCNFNPTPWN4IS6F...
# 219              37152666  SCRNBW3C6O2XCKFEHJIVOJRWSZU4BGOWRBA4ZW47I4KSO4...
# ...                   ...                                                ...
# 4075504          25251368  4PEKWTOO354GEIBDPYRSBLI3TJBD4MUX7GAEWX3SVIM2MQ...
# 4075505          25251368  LQ35MVT522XPGTMNPLJUK2AXCMXDAZWOOZQP4HQQXVD7SO...
# 4075506          25251368  XRNZYBMMKXVYERQ4GLPKZYU6F535M2EEBGDDQSX25JKESV...
# 4075507          25251368  DBVUZKLQONUI3WMGEF5TTWYV46S2HEFLROS5MYU634YAJL...
# 4075508          25251368  KHZWQLEQ5S5PZ6WASS27Q5GDMDQMTBVVKQD3NXVELQJJDD...
#
# ...

# %% [markdown]
# Filtering images with Tags that less likely depict any Landmarks - Based on what I observe from work I can say that usually indoor areas (except living room and bedroom that could have a view) wouldn't have a Landmark

# %%
words_to_drop = ['living-room', 'bathroom', 'kitchenette-kitchen', 'food_drinks', 'reception']
df_filt_tag= df_filt_dist[~df_filt_dist['tag_name'].isin(words_to_drop)]
df_filt_tag
# Out:
#          accommodation_id                                           image_id  \
# 215              37152666  JSC6NLCCJITBM4CUILH2O53RHDOMSTPY6AA2MWV63DJ4DH...
# 218              37152666  URBVFX5ELYSTMNB3K7V4NQEJ7GK7RT4BCNFNPTPWN4IS6F...
# 219              37152666  SCRNBW3C6O2XCKFEHJIVOJRWSZU4BGOWRBA4ZW47I4KSO4...
# 220              37152666  7TXXMNZKNOHLS5ITSP6UZRMJZUALGQ7GF6TD2AWP7KSL4O...
# 221              37152666  6X7PNLW7LAHCHVJITKFK7XNT7PGTLBMJQI6O7O5ZBQDSKQ...
# ...                   ...                                                ...
# 4075502          25251368  LDBSZFQWMDLM7372WHFUOLRZIUFKCYJEVL7MTUASWUMLJG...
# 4075503          25251368  6TGDXBUPYPJ73HKMJNJYIVKPBOXN3T256HAUWERWZCXEC6...
# 4075504          25251368  4PEKWTOO354GEIBDPYRSBLI3TJBD4MUX7GAEWX3SVIM2MQ...
# 4075505          25251368  LQ35MVT522XPGTMNPLJUK2AXCMXDAZWOOZQP4HQQXVD7SO...
# 4075507          25251368  DBVUZKLQONUI3WMGEF5TTWYV46S2HEFLROS5MYU634YAJL...
#
# ...

# %%
len_df_distance = len(df_filt_dist)
len_df_distance_tag = len(df_filt_tag)
print("Original size of dataframe = ", len_df)
perc_discarded_img= 100 - (len_df_distance/len_df *100)
print("Perctange of discarded images- distance filter = ",perc_discarded_img)
perc_discarded_img= 100 - (len_df_distance_tag/len_df *100)
print("Perctange of discarded images- tag & distance filter = ",perc_discarded_img) 
print("Filtered Size of dataframe = ", len_df_distance_tag)
# Out:
# Original size of dataframe =  4077935
# Perctange of discarded images- distance filter =  92.07711746263735
# Perctange of discarded images- tag & distance filter =  96.0607758583695
# Filtered Size of dataframe =  160639

# %%
data_filtered=df_filt_tag.drop_duplicates(subset=['accommodation_id'], keep='first')[['accommodation_id', 'longitude', 'latitude']]

print(data_filtered)
# Out:
#          accommodation_id  longitude  latitude
# 215              37152666   -0.07914  51.49986
# 319              37152184   -0.17578  51.54975
# 510              37151070   -0.15444  51.49080
# 598              37150914   -0.11255  51.52304
# 1220             37148164   -0.18406  51.51616
# ...                   ...        ...       ...
# 4068410          25268132   -0.12599  51.51801
# 4068505          25267758   -0.11262  51.49000
# 4074287          25254660   -0.18642  51.51358
# 4074661          25253350   -0.12750  51.50722
# 4075494          25251368   -0.18497  51.51350
#
# [15259 rows x 3 columns]

# %% [markdown]
# Call the Distance Matrix API to calculate driving, walking and transit durations based on the distance of each accommodation from the POI

# %%
def get_duration(api_key, start_lat, start_lng, end_lat, end_lng, mode):
    base_url = "https://maps.googleapis.com/maps/api/distancematrix/json"
    parameters = {
        'origins': f"{start_lat},{start_lng}",
        'destinations': f"{end_lat},{end_lng}",
        'mode': mode,
        'key': api_key
    }
    response = requests.get(base_url, params=parameters)
    data = response.json()

    if data['status'] == 'OK':
        duration = data['rows'][0]['elements'][0]['duration']['text']
        return duration
    else:
        return "Error: " + data['status']

# %% [markdown]
# Replace these with your API key and coordinates

# %%
api_key = 'AIzaSyD3UCQwzaxzdqZdx3NkgABCm7aYXxu2RT4'

# Calculate driving duration from property to Big Ben

data_filtered['driving_duration'] = data_filtered.apply(lambda row: get_duration(api_key, row['latitude'], row['longitude'], 51.510357, -0.116773, 'driving'), axis=1)

# Calculate walking duration from property to Big Ben

data_filtered['walking_duration'] = data_filtered.apply(lambda row: get_duration(api_key, row['latitude'], row['longitude'], 51.510357, -0.116773, 'walking'), axis=1)

# Calculate Transit duration from property to Big Ben

data_filtered['transit_duration'] = data_filtered.apply(lambda row: get_duration(api_key, row['latitude'], row['longitude'], 51.510357, -0.116773, 'transit'), axis=1)

# %%
def convert_to_minutes(duration_str):
    total_minutes = 0
    parts = duration_str.split()

    for i in range(0, len(parts), 2):  # Iterate in steps of 2
        value = int(parts[i])
        unit = parts[i + 1]

        if 'hour' in unit:
            total_minutes += value * 60
        elif 'min' in unit:
            total_minutes += value

    return total_minutes

# %%
data_filtered['driving_duration'] = data_filtered['driving_duration'].apply(convert_to_minutes)
data_filtered['walking_duration'] = data_filtered['walking_duration'].apply(convert_to_minutes)
data_filtered['transit_duration'] = data_filtered['transit_duration'].apply(convert_to_minutes)

# %%
data_filtered
# Out:
#          accommodation_id  longitude  latitude  driving_duration  \
# 215              37152666   -0.07914  51.49986                13
# 319              37152184   -0.17578  51.54975                27
# 510              37151070   -0.15444  51.49080                16
# 598              37150914   -0.11255  51.52304                10
# 1220             37148164   -0.18406  51.51616                24
# ...                   ...        ...       ...               ...
# 4068410          25268132   -0.12599  51.51801                10
# 4068505          25267758   -0.11262  51.49000                12
# 4074287          25254660   -0.18642  51.51358                23
# 4074661          25253350   -0.12750  51.50722                 4
# 4075494          25251368   -0.18497  51.51350                22
#
#          walking_duration  transit_duration
# 215                    49                25
# 319                    97                43
# 510                    56                10
# ...

# %%
merged_data_filtered = pd.merge(data_filtered, df_filt_tag, on=['accommodation_id', 'longitude', 'latitude'], how='right')
merged_data_filtered
# Out:
#         accommodation_id  longitude  latitude  driving_duration  \
# 0               37152666   -0.07914  51.49986                13
# 1               37152666   -0.07914  51.49986                13
# 2               37152666   -0.07914  51.49986                13
# 3               37152666   -0.07914  51.49986                13
# 4               37152666   -0.07914  51.49986                13
# ...                  ...        ...       ...               ...
# 160634          25251368   -0.18497  51.51350                22
# 160635          25251368   -0.18497  51.51350                22
# 160636          25251368   -0.18497  51.51350                22
# 160637          25251368   -0.18497  51.51350                22
# 160638          25251368   -0.18497  51.51350                22
#
#         walking_duration  transit_duration  \
# 0                     49                25
# 1                     49                25
# 2                     49                25
# ...

# %%
condition = (merged_data_filtered['driving_duration'] <= 10) | (merged_data_filtered['walking_duration'] <= 20) | (merged_data_filtered['transit_duration'] <= 20)

# Drop the rows based on the condition
merged_data_filtered= merged_data_filtered[condition]

# %%
len_final_df= len(merged_data_filtered)
print("Size of Df Final",len_final_df)
perc_discarded_img= 100 - (len_final_df/len_df *100)
print("Perctange of discarded images- duration filter = ",perc_discarded_img)
# Out:
# Size of Df Final 76676
# Perctange of discarded images- duration filter =  98.11973462058616

# %%
merged_data_filtered.to_csv('data_filtered_google_vision_input.csv', index=False)
